# %%
import pandas as pd
import csv
import re

# %%
Location = r'/home/prachi/Python_Pandas/input.csv'
df = pd.read_csv(Location)

# %%
mylist = [['JobTitle',"Date", "PositionDuration", "PositionLocation", "JobDescription", "JobResponsibilities", "RequiredQualifications", "Remuneration", "ApplicationDeadline", "AboutCompany"]]
    
myFile = open('output.csv', 'w')
with myFile:
    writer = csv.writer(myFile)
    writer.writerows(mylist)
print("Writing complete")
# Out:
# Writing complete

# %%
Loc = r'/home/prachi/Python_Pandas/output.csv'
df1 = pd.read_csv(Loc)
df1
# Out:
# Empty DataFrame
# Columns: [JobTitle, Date, PositionDuration, PositionLocation, JobDescription, JobResponsibilities, RequiredQualifications, Remuneration, ApplicationDeadline, AboutCompany]
# Index: []

# %%
df1.ApplicationDeadline = df.Deadline
df1.JobDescription = df.JobDescription
df1.JobResponsibilities = df.JobRequirment
df1.RequiredQualifications = df.RequiredQual
df1.AboutCompany = df.AboutC
df1.PositionDuration = df.Duration
df1.PositionLocation = df.Location
df1.JobTitle = df.Title
df1.Remuneration = df.Salary
df['date'] = pd.to_datetime(df.date, errors = 'coerce')
df1.Date = df.date
df1

#write extracted data back to newly created csv file
df1.to_csv('output.csv')



df1['year'] = df1['Date'].dt.year
df1['month'] = df1['Date'].dt.month
# df1['year']
# result = df.date
# res = []
# for i in range(0,len(result)):
#     res.append(re.split(r',',result[i]))
# #print(res)

# data = pd.DataFrame(res)
# data.columns = ['month','year']
# #data
# df1.JobPostMonth = data.month
# df1.JobPostYear = data.year
# #df1

# temp = df1.JobPostMonth
# t = []
# for i in range(0, len(temp)):
#     t.append(re.split(r' ',temp[i]))
# #print(t)
# tdf = pd.DataFrame(t)
# data.colums = ['month', 'date']

# %%
c = df1.sort_values('year', ascending=False)
c
# Out:
#                                                 JobTitle       Date  \
# 19000                         Lawyer in Legal Department 2015-12-30
# 18199              B2B Operations and Support Specialist 2015-08-07
# 18201  Expert in Performing Financial Due Diligence o... 2015-08-07
# 18202    Fixed Mobile Convergent Services Senior Manager 2015-08-07
# 18203                                  Marketing Manager 2015-08-07
# 18204                                       Receptionist 2015-08-07
# 18205                   Tuberculosis Program Coordinator 2015-08-09
# 18206                      HIV/ AIDS Program Coordinator 2015-08-09
# 18207                          Quality Assurance Analyst 2015-08-09
# 18208        Junior Data Analysis and Reporting Engineer 2015-08-10
# 18209       Business Intelligence and Reporting Engineer 2015-08-09
# 18210                     Head of SME Lending Department 2015-08-10
# 18211                               Gavar Branch Manager 2015-08-10
# ...

# %%
d = c.loc[df1['year'].isin(['2014','2015'])]
d
# Out:
#                                                 JobTitle       Date  \
# 19000                         Lawyer in Legal Department 2015-12-30
# 18199              B2B Operations and Support Specialist 2015-08-07
# 18201  Expert in Performing Financial Due Diligence o... 2015-08-07
# 18202    Fixed Mobile Convergent Services Senior Manager 2015-08-07
# 18203                                  Marketing Manager 2015-08-07
# 18204                                       Receptionist 2015-08-07
# 18205                   Tuberculosis Program Coordinator 2015-08-09
# 18206                      HIV/ AIDS Program Coordinator 2015-08-09
# 18207                          Quality Assurance Analyst 2015-08-09
# 18208        Junior Data Analysis and Reporting Engineer 2015-08-10
# 18209       Business Intelligence and Reporting Engineer 2015-08-09
# 18210                     Head of SME Lending Department 2015-08-10
# 18211                               Gavar Branch Manager 2015-08-10
# ...

# %%
g = d.groupby(['AboutCompany'])

# %%
f = g.count()
f
# Out:
#                                                     JobTitle  Date  \
# AboutCompany
# "4H" LLC is a software development company, con...         1     1
# "ACRA Credit Reporting" CJSC is a Credit bureau...         1     1
# "Accurate Group" LLC is a vertically integrated...         1     1
# "Anelik Bank" CJSC is a commercial bank which h...         4     4
# "Anelik Bank" CJSC is a universal commercial ba...         1     1
# "Anelik Bank" CJSC is a universal commercial ba...         1     1
# "Arantsk" NGO is a non-profit organization whic...         4     4
# "Aregak" UCO CJSC was founded in 2006. It provi...         1     1
# "Aregak" UCO CJSC was founded in 2006. The orga...         1     1
# "Aregak" Universal Credit Organization CJSC was...         4     4
# "Aregak" has started its activity as a microcre...         1     1
# "Aregak" has started its activity as a microcre...         1     1
# "Aregak" has started its activity as a microcre...         2     2
# ...

# %%
c = f.sort_values('year', ascending=False)
c
# Out:
#                                                     JobTitle  Date  \
# AboutCompany
# Mentor Graphics Development Services CJSC is a ...        64    64
# For more information please visit: www.questrad...        22    22
# Joomag AM LLC provides digital publishing servi...        15    15
# For information about Converse Bank CJSC, pleas...        15    15
# The main purpose of the SA Center for Education...        14    14
# Joomag AM LLC is a digital publishing company. ...        13    13
# VMware, Inc. is an American software company th...        13    13
# CARD is an impact-based organization originatin...        12    12
# Energize Global Services CJSC is a software dev...        11    11
# For more information, please visit: www.questra...        11    11
# Energize Global Services CJSC is a software dev...        10    10
# BetArchitect is a software development company,...        10    10
# "Ucom" LLC telecom company provides network and...        10    10
# ...

# %%
c[:2]
# Out:
#                                                     JobTitle  Date  \
# AboutCompany
# Mentor Graphics Development Services CJSC is a ...        64    64
# For more information please visit: www.questrad...        22    22
#
#                                                     PositionDuration  \
# AboutCompany
# Mentor Graphics Development Services CJSC is a ...                60
# For more information please visit: www.questrad...                 0
#
#                                                     PositionLocation  \
# AboutCompany
# Mentor Graphics Development Services CJSC is a ...                64
# For more information please visit: www.questrad...                22
#
#                                                     JobDescription  \
# AboutCompany
# Mentor Graphics Development Services CJSC is a ...              63
# For more information please visit: www.questrad...              21
#
#                                                     JobResponsibilities  \
# ...

# %%
identify the month with max number of job ads
# Out:
#   File "<ipython-input-12-1f0455f0d45f>", line 1
#     identify the month with max number of job ads
#                ^
# SyntaxError: invalid syntax

# %%
p = df1.sort_values('month')
a = p.groupby(['month'])

# %%
y = a.count()
w = y.sort_values('JobTitle', ascending = False)
w.head(1)

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /home/prachi/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /home/prachi/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /home/prachi/nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /home/prachi/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /home/prachi/nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /home/prachi/nltk_data...
# ...

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import * 

#data = str(df1.JobResponsibilities)
#print(data)
stopWords = set(stopwords.words('english'))
words = word_tokenize(data)
wordsFiltered = []

for w in words:
    if w not in stopWords:
        wordsFiltered.append(w)
 
#print(wordsFiltered)


#plural to singular
stemmer = PorterStemmer()

singles = [stemmer.stem(plural) for plural in wordsFiltered]
print(' '.join(singles))
# Out:
# 0 - supervis financi manag administ ... 1 nan 2 - work countri director provid ... 3 - identifi gap knowledg overse ... 4 - render technic assist databas M ... 5 nan 6 nan 7 nan 8 - coordin work subordin employ ... 9 nan 10 nan 11 nan 12 nan 13 - assist tavush marz commun commu ... 14 - manag control compani 's activ ... 15 - network monitor administr ; \r\n- ... 16 nan 17 the incumb direct supervis undp ... 18 - maintain chap/armenia pool vehicl p ... 19 graphic design respons everi ... 20 - respons manag offic administrati ... 21 - draw jurid document ; \r\n- draw ... 22 - lead effort identifi target oppor ... 23 - overal manag oper directio ... 24 nan 25 - assist program director aspect ... 26 nan 27 nan 28 nan 29 nan ... 18971 - answer telephon call inquiri , forwar ... 18972 - develop softwar code base exist ... 18973 - respons develop build high ... 18974 - respons cad librari includ mo ... 18975 - respons data collect analysi ... 18976 - prepar annual budget , monthli forecast
# ...

# %%
from nltk.stem.porter import *

stemmer = PorterStemmer()

#Test the stemmer on various pluralised words.

plurals = ['caresses', 'flies', 'dies', 'mules', 'denied','died', 'agreed', 'owned', 'humbled', 'sized','meeting', 'stating', 'siezing', 'itemization','sensational', 'traditional', 'reference', 'colonizer','plotted']
singles = [stemmer.stem(plural) for plural in plurals]
print(' '.join(singles))

# %%
 
# replacing na values with custome message="Hello"
df1["PositionDuration"].fillna("Hello", inplace = True)
 
df1.PositionDuration
# Out:
# 0                                                    Hello
# 1                                                 3 months
# 2                    Renewable annual contract\r\nPOSITION
# 3                                                    Hello
# 4                                                    Hello
# 5                                                    Hello
# 6                                                    Hello
# 7                                                 6 months
# 8                                                    Hello
# 9                                                    Hello
# 10                                                   Hello
# 11                                                6 months
# 12                                      5 year\r\nPOSITION
# 13                                                   Hello
# 14                                                   Hello
# 15                                                   Hello
# ...

# %%
# I=df1.groupby("year").sum()[df1.'AboutCompany'].plot(figsize=(20,10));
# I.set_xlabel('Year')
# I.set_ylabel('AboutCompany')
# # I.set_title('Average annual rainfall')
